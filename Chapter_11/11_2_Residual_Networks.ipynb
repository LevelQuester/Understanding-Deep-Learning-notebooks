# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap11/11_2_Residual_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 11.2: Residual Networks**
#
# This notebook adapts the networks for MNIST1D to use residual connections.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /private/var/folders/c4/lv8ynhxj00s4xm6_h9kt_byh0000gn/T/pip-req-build-b_0g1_7w
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /private/var/folders/c4/lv8ynhxj00s4xm6_h9kt_byh0000gn/T/pip-req-build-b_0g1_7w
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /opt/homebrew/Caskroom/miniforge/base/envs/nb312/lib/python3.12/site-packages (from mnist1d==0.0.2.post16) (2.32.5)
# Requirement already satisfied: numpy in /opt/homebrew/Caskroom/miniforge/base/envs/nb312/lib/python3.12/site-packages (from mnist1d==0.0.2.post16) (2.3.5)
# Requirement already satisfied: matplotlib in /opt/homebrew/Caskroom/miniforge/base/envs/nb312/lib/python3.12/site-packages (from mnist1d==0.0.2.post16) (3.10.7)
# Requirement already satisfied: scipy in /opt/homebrew/Caskroom/miniforge/base/envs/nb312/lib/python3.12/site-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/Caskroom/miniforge/base/envs/nb312/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/Caskroom/miniforge/base/envs/nb312/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/Caskroom/miniforge/base/envs/nb312/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/homebrew/Caskroom/miniforge/base/envs/nb312/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/Caskroom/miniforge/base/envs/nb312/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /opt/homebrew/Caskroom/miniforge/base/envs/nb312/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in /opt/homebrew/Caskroom/miniforge/base/envs/nb312/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/Caskroom/miniforge/base/envs/nb312/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Caskroom/miniforge/base/envs/nb312/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/Caskroom/miniforge/base/envs/nb312/lib/python3.12/site-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Caskroom/miniforge/base/envs/nb312/lib/python3.12/site-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/Caskroom/miniforge/base/envs/nb312/lib/python3.12/site-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/Caskroom/miniforge/base/envs/nb312/lib/python3.12/site-packages (from requests->mnist1d==0.0.2.post16) (2025.11.12)

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# We will adapt this model to have residual connections around the linear layers
# This is the same model we used in practical 8.1, but we can't use the sequential
# class for residual networks (which aren't strictly sequential).  Hence, I've rewritten
# it as a model that inherits from a base class
class ResidualNetwork(torch.nn.Module):
  def __init__(self, input_size, output_size, hidden_size=100):
    super(ResidualNetwork, self).__init__()
    self.linear1 = nn.Linear(input_size, hidden_size)
    self.linear2 = nn.Linear(hidden_size, hidden_size)
    self.linear3 = nn.Linear(hidden_size, hidden_size)
    self.linear4 = nn.Linear(hidden_size, output_size)
    print("Initialized MLPBase model with {} parameters".format(self.count_params()))

  def count_params(self):
    return sum([p.view(-1).shape[0] for p in self.parameters()])

# TODO -- Add residual connections to this model
# The order of operations within each block should similar to figure 11.5b
# ie., linear1 first, ReLU+linear2 in first residual block, ReLU+linear3 in second residual block), linear4 at end
# Replace this function
  def forward(self, x):
    # linear1 first
    h1 = self.linear1(x)
    # ReLU+linear2 in first residual block (h = h + L(ReLU(h)))
    h2 = h1 + self.linear2(h1.relu())
    # ReLU+linear3 in second residual block
    h3 = h2 + self.linear3(h2.relu())
    # linear4 at end (applying relu before final projection is standard for this architecture style)
    return self.linear4(h3.relu())

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
#Define the model
model = ResidualNetwork(40, 10)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initialized MLPBase model with 25310 parameters
# Epoch     0, train loss 1.592390, train error 61.40,  val loss 1.671759, percent error 67.10
# Epoch     1, train loss 1.255749, train error 47.60,  val loss 1.439873, percent error 56.90
# Epoch     2, train loss 1.055253, train error 39.47,  val loss 1.314858, percent error 52.00
# Epoch     3, train loss 0.886060, train error 31.80,  val loss 1.239274, percent error 48.10
# Epoch     4, train loss 0.773934, train error 27.90,  val loss 1.172635, percent error 45.40
# Epoch     5, train loss 0.679913, train error 23.93,  val loss 1.189513, percent error 44.40
# Epoch     6, train loss 0.613423, train error 22.70,  val loss 1.195300, percent error 42.50
# Epoch     7, train loss 0.553460, train error 19.82,  val loss 1.131541, percent error 41.50
# Epoch     8, train loss 0.428898, train error 14.70,  val loss 1.145745, percent error 37.80
# Epoch     9, train loss 0.373626, train error 12.10,  val loss 1.112546, percent error 36.80
# Epoch    10, train loss 0.309327, train error 10.05,  val loss 1.148438, percent error 37.70
# Epoch    11, train loss 0.282713, train error 9.62,  val loss 1.329154, percent error 40.50
# Epoch    12, train loss 0.254484, train error 8.18,  val loss 1.295741, percent error 36.90
# Epoch    13, train loss 0.188290, train error 6.30,  val loss 1.340226, percent error 39.10
# Epoch    14, train loss 0.144462, train error 3.70,  val loss 1.342264, percent error 35.90
# Epoch    15, train loss 0.148180, train error 4.43,  val loss 1.438425, percent error 36.90
# Epoch    16, train loss 0.120806, train error 3.38,  val loss 1.381804, percent error 37.50
# Epoch    17, train loss 0.121761, train error 4.00,  val loss 1.596787, percent error 36.80
# Epoch    18, train loss 0.135050, train error 4.15,  val loss 1.643819, percent error 37.20
# Epoch    19, train loss 0.088202, train error 2.45,  val loss 1.576683, percent error 36.50
# Epoch    20, train loss 0.028631, train error 0.12,  val loss 1.458837, percent error 34.60
# Epoch    21, train loss 0.015915, train error 0.03,  val loss 1.509425, percent error 34.50
# Epoch    22, train loss 0.011935, train error 0.00,  val loss 1.553156, percent error 34.70
# Epoch    23, train loss 0.010186, train error 0.00,  val loss 1.558401, percent error 33.80
# Epoch    24, train loss 0.009047, train error 0.00,  val loss 1.586032, percent error 34.00
# Epoch    25, train loss 0.008173, train error 0.00,  val loss 1.608442, percent error 33.60
# Epoch    26, train loss 0.007450, train error 0.00,  val loss 1.625661, percent error 33.60
# Epoch    27, train loss 0.006854, train error 0.00,  val loss 1.636654, percent error 33.40
# Epoch    28, train loss 0.006376, train error 0.00,  val loss 1.656577, percent error 33.50
# Epoch    29, train loss 0.005932, train error 0.00,  val loss 1.669187, percent error 33.60
# Epoch    30, train loss 0.005572, train error 0.00,  val loss 1.681492, percent error 33.40
# Epoch    31, train loss 0.005274, train error 0.00,  val loss 1.696428, percent error 33.60
# Epoch    32, train loss 0.004990, train error 0.00,  val loss 1.706345, percent error 33.80
# Epoch    33, train loss 0.004723, train error 0.00,  val loss 1.717453, percent error 33.40
# Epoch    34, train loss 0.004495, train error 0.00,  val loss 1.728586, percent error 33.60
# Epoch    35, train loss 0.004290, train error 0.00,  val loss 1.734975, percent error 33.60
# Epoch    36, train loss 0.004094, train error 0.00,  val loss 1.746128, percent error 33.60
# Epoch    37, train loss 0.003924, train error 0.00,  val loss 1.754279, percent error 33.60
# Epoch    38, train loss 0.003761, train error 0.00,  val loss 1.766880, percent error 33.90
# Epoch    39, train loss 0.003616, train error 0.00,  val loss 1.772640, percent error 33.50
# Epoch    40, train loss 0.003544, train error 0.00,  val loss 1.777203, percent error 33.90
# Epoch    41, train loss 0.003479, train error 0.00,  val loss 1.780968, percent error 33.70
# Epoch    42, train loss 0.003414, train error 0.00,  val loss 1.785467, percent error 34.20
# Epoch    43, train loss 0.003354, train error 0.00,  val loss 1.788449, percent error 33.90
# Epoch    44, train loss 0.003295, train error 0.00,  val loss 1.793202, percent error 34.20
# Epoch    45, train loss 0.003240, train error 0.00,  val loss 1.797270, percent error 34.20
# Epoch    46, train loss 0.003186, train error 0.00,  val loss 1.800549, percent error 34.20
# Epoch    47, train loss 0.003133, train error 0.00,  val loss 1.804699, percent error 34.20
# Epoch    48, train loss 0.003082, train error 0.00,  val loss 1.808263, percent error 34.20
# Epoch    49, train loss 0.003034, train error 0.00,  val loss 1.812068, percent error 34.20
# Epoch    50, train loss 0.002985, train error 0.00,  val loss 1.814621, percent error 34.20
# Epoch    51, train loss 0.002938, train error 0.00,  val loss 1.817951, percent error 34.00
# Epoch    52, train loss 0.002893, train error 0.00,  val loss 1.821422, percent error 34.10
# Epoch    53, train loss 0.002849, train error 0.00,  val loss 1.825547, percent error 34.10
# Epoch    54, train loss 0.002807, train error 0.00,  val loss 1.827514, percent error 34.10
# Epoch    55, train loss 0.002765, train error 0.00,  val loss 1.831337, percent error 34.00
# Epoch    56, train loss 0.002726, train error 0.00,  val loss 1.834602, percent error 34.20
# Epoch    57, train loss 0.002686, train error 0.00,  val loss 1.837718, percent error 34.00
# Epoch    58, train loss 0.002649, train error 0.00,  val loss 1.840765, percent error 34.10
# Epoch    59, train loss 0.002612, train error 0.00,  val loss 1.843446, percent error 34.10
# Epoch    60, train loss 0.002593, train error 0.00,  val loss 1.844942, percent error 34.20
# Epoch    61, train loss 0.002575, train error 0.00,  val loss 1.846973, percent error 34.10
# Epoch    62, train loss 0.002558, train error 0.00,  val loss 1.848486, percent error 34.20
# Epoch    63, train loss 0.002541, train error 0.00,  val loss 1.849447, percent error 34.10
# Epoch    64, train loss 0.002524, train error 0.00,  val loss 1.850796, percent error 34.10
# Epoch    65, train loss 0.002507, train error 0.00,  val loss 1.852851, percent error 34.10
# Epoch    66, train loss 0.002490, train error 0.00,  val loss 1.853968, percent error 34.10
# Epoch    67, train loss 0.002474, train error 0.00,  val loss 1.855520, percent error 34.10
# Epoch    68, train loss 0.002458, train error 0.00,  val loss 1.856534, percent error 34.10
# Epoch    69, train loss 0.002442, train error 0.00,  val loss 1.858042, percent error 34.10
# Epoch    70, train loss 0.002426, train error 0.00,  val loss 1.859682, percent error 34.10
# Epoch    71, train loss 0.002411, train error 0.00,  val loss 1.860631, percent error 34.10
# Epoch    72, train loss 0.002395, train error 0.00,  val loss 1.862154, percent error 34.10
# Epoch    73, train loss 0.002380, train error 0.00,  val loss 1.863408, percent error 34.10
# Epoch    74, train loss 0.002365, train error 0.00,  val loss 1.865081, percent error 34.10
# Epoch    75, train loss 0.002351, train error 0.00,  val loss 1.866288, percent error 34.10
# Epoch    76, train loss 0.002336, train error 0.00,  val loss 1.868237, percent error 34.10
# Epoch    77, train loss 0.002321, train error 0.00,  val loss 1.868752, percent error 34.10
# Epoch    78, train loss 0.002307, train error 0.00,  val loss 1.870966, percent error 34.10
# Epoch    79, train loss 0.002293, train error 0.00,  val loss 1.871942, percent error 34.10
# Epoch    80, train loss 0.002286, train error 0.00,  val loss 1.872594, percent error 34.10
# Epoch    81, train loss 0.002279, train error 0.00,  val loss 1.873234, percent error 34.10
# Epoch    82, train loss 0.002272, train error 0.00,  val loss 1.873932, percent error 34.10
# Epoch    83, train loss 0.002265, train error 0.00,  val loss 1.874473, percent error 34.10
# Epoch    84, train loss 0.002259, train error 0.00,  val loss 1.875119, percent error 34.10
# Epoch    85, train loss 0.002252, train error 0.00,  val loss 1.876020, percent error 34.10
# Epoch    86, train loss 0.002245, train error 0.00,  val loss 1.876292, percent error 34.10
# Epoch    87, train loss 0.002238, train error 0.00,  val loss 1.877064, percent error 34.10
# Epoch    88, train loss 0.002232, train error 0.00,  val loss 1.877449, percent error 34.10
# Epoch    89, train loss 0.002225, train error 0.00,  val loss 1.878112, percent error 34.10
# Epoch    90, train loss 0.002218, train error 0.00,  val loss 1.879109, percent error 34.10
# Epoch    91, train loss 0.002212, train error 0.00,  val loss 1.879574, percent error 34.10
# Epoch    92, train loss 0.002205, train error 0.00,  val loss 1.880360, percent error 34.10
# Epoch    93, train loss 0.002199, train error 0.00,  val loss 1.881063, percent error 34.10
# Epoch    94, train loss 0.002192, train error 0.00,  val loss 1.881673, percent error 34.10
# Epoch    95, train loss 0.002186, train error 0.00,  val loss 1.882157, percent error 34.10
# Epoch    96, train loss 0.002180, train error 0.00,  val loss 1.882728, percent error 34.10
# Epoch    97, train loss 0.002173, train error 0.00,  val loss 1.883676, percent error 34.10
# Epoch    98, train loss 0.002167, train error 0.00,  val loss 1.884182, percent error 34.10
# Epoch    99, train loss 0.002161, train error 0.00,  val loss 1.884772, percent error 34.10

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# The primary motivation of residual networks is to allow training of much deeper networks.
#
# TODO: Try running this network with and without the residual connections.  Does adding the residual connections change the performance?
